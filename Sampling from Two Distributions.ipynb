# %%
using Gadfly 
using Distributions
using KernelEstimator
using StatsBase

# %% [markdown]
# As a test case, consider an array of salarys for males (**M_Salary**) and females (**F_Salary**). For simplicity, our arrays will be equal in length and have **J** elements. To populate each array, we will sample from a [Gamma distribution](https://en.wikipedia.org/wiki/Gamma_distribution), $Gamma(α,β)$, with shape parameter $α$ and scale $β$.
#
# $$ f(x; \alpha, \beta) = \frac{x^{\alpha-1} e^{-x/\beta}}{\Gamma(\alpha) \beta^\alpha}, \quad x > 0$$

# %%
J = 1000;

# %% [markdown]
# Populate our arrays:

# %%
α = 5
d = Gamma(α);
M_Salary = 3+rand(d,J);
F_Salary = rand(d,J);

# %%
P1 = plot(x=M_Salary,Geom.histogram(bincount=50),Coord.Cartesian(xmin=0, xmax=20),Guide.title("M_Salary"))
P2 = plot(x=F_Salary, Geom.histogram(bincount=50), Theme(default_color=colorant"red"),Coord.Cartesian(xmin=0, xmax=20),
Guide.title("F_Salary"))
display(vstack(P1,P2))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink"
#      xmlns:gadfly="http://www.gadflyjl.org/ns"
#      version="1.2"
#      width="141.42mm" height="100mm" viewBox="0 0 141.42 100"
#      stroke="none"
#      fill="#000000"
#      stroke-width="0.3"
#      font-size="3.88"
#
#      id="img-23757018">
# <g class="plotroot xscalable yscalable" id="img-23757018-1">
#   <g font-size="3.88" font-family="'PT Sans','Helvetica Neue','Helvetica',sans-serif" fill="#564A55" stroke="#000000" stroke-opacity="0.000" id="img-23757018-2">
#     <text x="73.38" y="88.39" text-anchor="middle" dy="0.6em">x</text>
#   </g>
#   <g class="guide xlabels" font-size="2.82" font-family="'PT Sans Caption','Helvetica Neue','Helvetica',sans-serif" fill="#6C606B" id="img-23757018-3">
#     <text x="-140.25" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">-25</text>
#     <text x="-109.73" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">-20</text>
#     <text x="-79.21" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">-15</text>
#     <text x="-48.69" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">-10</text>
#     <text x="-18.17" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">-5</text>
#     <text x="12.35" y="84.39" text-anchor="middle" visibility="visible" gadfly:scale="1.0">0</text>
#     <text x="42.87" y="84.39" text-anchor="middle" visibility="visible" gadfly:scale="1.0">5</text>
#     <text x="73.38" y="84.39" text-anchor="middle" visibility="visible" gadfly:scale="1.0">10</text>
#     <text x="103.9" y="84.39" text-anchor="middle" visibility="visible" gadfly:scale="1.0">15</text>
#     <text x="134.42" y="84.39" text-anchor="middle" visibility="visible" gadfly:scale="1.0">20</text>
#     <text x="164.94" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">25</text>
#     <text x="195.46" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">30</text>
#     <text x="225.98" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">35</text>
#     <text x="256.5" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">40</text>
#     <text x="287.01" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">45</text>
#     <text x="-109.73" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-20</text>
#     <text x="-103.62" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-19</text>
#     <text x="-97.52" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-18</text>
#     <text x="-91.42" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-17</text>
#     <text x="-85.31" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-16</text>
#     <text x="-79.21" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-15</text>
#     <text x="-73.11" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-14</text>
#     <text x="-67" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-13</text>
#     <text x="-60.9" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-12</text>
#     <text x="-54.79" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-11</text>
#     <text x="-48.69" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-10</text>
#     <text x="-42.59" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-9</text>
#     <text x="-36.48" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-8</text>
#     <text x="-30.38" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-7</text>
#     <text x="-24.28" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-6</text>
#     <text x="-18.17" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-5</text>
#     <text x="-12.07" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-4</text>
#     <text x="-5.96" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-3</text>
#     <text x="0.14" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-2</text>
#     <text x="6.24" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-1</text>
#     <text x="12.35" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">0</text>
#     <text x="18.45" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">1</text>
#     <text x="24.55" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">2</text>
#     <text x="30.66" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">3</text>
#     <text x="36.76" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">4</text>
#     <text x="42.87" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">5</text>
#     <text x="48.97" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">6</text>
#     <text x="55.07" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">7</text>
#     <text x="61.18" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">8</text>
#     <text x="67.28" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">9</text>
#     <text x="73.38" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">10</text>
#     <text x="79.49" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">11</text>
#     <text x="85.59" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">12</text>
#     <text x="91.7" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">13</text>
#     <text x="97.8" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">14</text>
#     <text x="103.9" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">15</text>
#     <text x="110.01" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">16</text>
#     <text x="116.11" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">17</text>
#     <text x="122.21" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">18</text>
#     <text x="128.32" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">19</text>
#     <text x="134.42" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">20</text>
#     <text x="140.53" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">21</text>
#     <text x="146.63" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">22</text>
#     <text x="152.73" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">23</text>
#     <text x="158.84" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">24</text>
#     <text x="164.94" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">25</text>
#     <text x="171.04" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">26</text>
#     <text x="177.15" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">27</text>
#     <text x="183.25" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">28</text>
#     <text x="189.35" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">29</text>
#     <text x="195.46" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">30</text>
#     <text x="201.56" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">31</text>
#     <text x="207.67" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">32</text>
#     <text x="213.77" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">33</text>
#     <text x="219.87" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">34</text>
#     <text x="225.98" y="84.39" text-anchor="middle" visibility="hidden" gadfl

# %% [markdown]
# # Sampling Ad Nauseam
# Randomly sample from **M_Salary** and **F_Salary** with replacement. We will do this **k** times with each element of **M/F_salary** having equal probability (**w**) of being sampled.

# %%
k = 10000000;
w = repmat([1],J);

# %% [markdown]
# Perform the sampling:

# %%
M_s = wsample(M_Salary,w,k);
F_s = wsample(F_Salary,w,k);

# %%
R1 = sum(F_s.>M_s)/length(F_s)
# Out:
# 0.1566768

# %% [markdown]
# # Without Sampling
# For generality, let $X>0$ and $Y>0$ be two random variables.
# Let $f_Y(y)$ be the probability density function for $Y$ and $F_X(y)$ be the cumulative density function for $X$, i.e. the integral of $f_X(y)$.
#
# $$ P(X<Y) = \int P(X<y)f_Y(y)dy = \int F_X(y)f_Y(y)dy $$
#
# Let **fY** = $f_Y(y)$ and **FX** = $F_X(y)$

# %%
# Create the function FX representing the cumulative density function for the male salaries
FX = ecdf(M_Salary) 

# Define the grid over which we want to evaluate the cumulative density function
x_grid = collect(.01:.01:20); 

# Evaluate the cumulative density function FX on the grid.
FXy = FX(x_grid);

# %%
# Create the PDF for the female salaries and evaluate it on the same grid.
fY = kerneldensity(F_Salary, xeval=x_grid, kernel=gaussiankernel); 

# Scale the result to ensure that the area under fY is equal to 1
fY = fY./sum(fY);

# %%
P3 = plot(x=x_grid,y=FXy,Geom.line,Guide.xlabel("Salaries"),Guide.ylabel("F<sub>X</sub> (salaries)"),
Guide.title("Cumulative Density Function for Male Salaries"))
P4 = plot(x=x_grid,y=fY,Geom.line,Guide.xlabel("Salaries"),Guide.ylabel("f<sub>Y</sub> (salaries)"),
Guide.title("Probability Density Function for Female Salaries"))
display(vstack(P3,P4))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink"
#      xmlns:gadfly="http://www.gadflyjl.org/ns"
#      version="1.2"
#      width="141.42mm" height="100mm" viewBox="0 0 141.42 100"
#      stroke="none"
#      fill="#000000"
#      stroke-width="0.3"
#      font-size="3.88"
#
#      id="img-affe5717">
# <g class="plotroot xscalable yscalable" id="img-affe5717-1">
#   <g font-size="3.88" font-family="'PT Sans','Helvetica Neue','Helvetica',sans-serif" fill="#564A55" stroke="#000000" stroke-opacity="0.000" id="img-affe5717-2">
#     <text x="87.83" y="88.39" text-anchor="middle" dy="0.6em">Salaries</text>
#   </g>
#   <g class="guide xlabels" font-size="2.82" font-family="'PT Sans Caption','Helvetica Neue','Helvetica',sans-serif" fill="#6C606B" id="img-affe5717-3">
#     <text x="-75.25" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">-25</text>
#     <text x="-51.95" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">-20</text>
#     <text x="-28.65" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">-15</text>
#     <text x="-5.36" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">-10</text>
#     <text x="17.94" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">-5</text>
#     <text x="41.24" y="84.39" text-anchor="middle" visibility="visible" gadfly:scale="1.0">0</text>
#     <text x="64.53" y="84.39" text-anchor="middle" visibility="visible" gadfly:scale="1.0">5</text>
#     <text x="87.83" y="84.39" text-anchor="middle" visibility="visible" gadfly:scale="1.0">10</text>
#     <text x="111.12" y="84.39" text-anchor="middle" visibility="visible" gadfly:scale="1.0">15</text>
#     <text x="134.42" y="84.39" text-anchor="middle" visibility="visible" gadfly:scale="1.0">20</text>
#     <text x="157.72" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">25</text>
#     <text x="181.01" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">30</text>
#     <text x="204.31" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">35</text>
#     <text x="227.61" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">40</text>
#     <text x="250.9" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="1.0">45</text>
#     <text x="-51.95" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-20</text>
#     <text x="-47.29" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-19</text>
#     <text x="-42.63" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-18</text>
#     <text x="-37.97" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-17</text>
#     <text x="-33.31" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-16</text>
#     <text x="-28.65" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-15</text>
#     <text x="-24" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-14</text>
#     <text x="-19.34" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-13</text>
#     <text x="-14.68" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-12</text>
#     <text x="-10.02" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-11</text>
#     <text x="-5.36" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-10</text>
#     <text x="-0.7" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-9</text>
#     <text x="3.96" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-8</text>
#     <text x="8.62" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-7</text>
#     <text x="13.28" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-6</text>
#     <text x="17.94" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-5</text>
#     <text x="22.6" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-4</text>
#     <text x="27.26" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-3</text>
#     <text x="31.92" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-2</text>
#     <text x="36.58" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">-1</text>
#     <text x="41.24" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">0</text>
#     <text x="45.89" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">1</text>
#     <text x="50.55" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">2</text>
#     <text x="55.21" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">3</text>
#     <text x="59.87" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">4</text>
#     <text x="64.53" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">5</text>
#     <text x="69.19" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">6</text>
#     <text x="73.85" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">7</text>
#     <text x="78.51" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">8</text>
#     <text x="83.17" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">9</text>
#     <text x="87.83" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">10</text>
#     <text x="92.49" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">11</text>
#     <text x="97.15" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">12</text>
#     <text x="101.81" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">13</text>
#     <text x="106.47" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">14</text>
#     <text x="111.12" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">15</text>
#     <text x="115.78" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">16</text>
#     <text x="120.44" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">17</text>
#     <text x="125.1" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">18</text>
#     <text x="129.76" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">19</text>
#     <text x="134.42" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">20</text>
#     <text x="139.08" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">21</text>
#     <text x="143.74" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">22</text>
#     <text x="148.4" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">23</text>
#     <text x="153.06" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">24</text>
#     <text x="157.72" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">25</text>
#     <text x="162.38" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">26</text>
#     <text x="167.04" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">27</text>
#     <text x="171.7" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">28</text>
#     <text x="176.36" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">29</text>
#     <text x="181.01" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">30</text>
#     <text x="185.67" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">31</text>
#     <text x="190.33" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">32</text>
#     <text x="194.99" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">33</text>
#     <text x="199.65" y="84.39" text-anchor="middle" visibility="hidden" gadfly:scale="10.0">34</text>
#     <text x="204.31" y="84.39" text-anchor="middle" visibility="hidden" gadfly:sc

# %% [markdown]
# To calculate the probability that a female salary selected at random will be larger than a male salary selected at random, multiply the cumulative density function for the male salaries by the probability density function for the female salaries and sum the result, i.e., $$ P(Male Salary<Female Salary) = P(X<Y) $$
# $$=  \int P(X<y)f_Y(y)dy = \int F_X(y)f_Y(y)dy $$
#
# **=sum(FXy*fY)**

# %%
R2 = sum(FXy.*fY)
# Out:
# 0.16102060072310953

# %%
# Compare this result to what we got by exhaustively sampling the male and female arrays of salaries:
R1-R2
# Out:
# -0.0043438007231095255
