# %% [markdown]
# # Sample Experimental Analysis

# %% [markdown]
# ### Preamble

# %%
using Gadfly
# Out:
# INFO: Precompiling module Gadfly...

# %% [markdown]
# The following data were collected at
#
# + 40X
# + Binning 1
# + Quickly

# %%
X = rand(100,2);
plot(x = X[:,1],y = X[:,2],Geom.line)
# Out:
# Plot(...)
